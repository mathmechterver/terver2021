# %% [markdown]
# # 1. Наивная вероятность. Геометрическая вероятность.

# %% [markdown]
# <img src='data/meme.png' width=300/>

# %% [markdown]
# ## Содержание
#
# * [Теория](#chapter1)
# * [Задачи на пару](#chapter2)
# * [Домашнее задание](#chapter3)
# * [Гробы](#chapter4)

# %% [markdown]
# ## Теория <a class="anchor" id="chapter1"></a>

# %% [markdown]
# Если элементарные исходы равновероятны
#
# $$P(A) = \frac{m}{n} = \frac{\textrm{хорошие исходы}}{\textrm{все исходов}}$$
#
# Если элементарные исходы неравновероятны
#
# $$P(A) = \frac{measure(A)}{measure(\Omega)}$$
#
# *measure* - некая мера, $\Omega$ - множество всех элементарных событий
#
#
# Число способов выбрать $k$ объектов из $n$ различных объектов.
# $$C_{n}^{k} = \frac{n!}{k!(n-k)!}$$
#
# Число перестановок
# $$P_n = n!$$

# %% [markdown]
# --------------

# %% [markdown]
# ## Задачи на пару <a class="anchor" id="chapter2"></a>

# %% [markdown]
# **1)** У нас есть правильный кубик. Какова вероятность выпадения:
# * При двух бросках, оба раза выпала единица
# * Сумма 2х бросков - 7
# * Сумма 3х бросков - 16

# %% [markdown]
# **2)** Перед нами рулетка с неравномерными полями. Посмотрите на картинку ниже и ответьте на вопросы:
# 1. Какова вероятность выпадения (1 и 2)
# 2. Какова вероятность выпадения (2 и 3)
#
# Объясните, почему не работает первая формула из теории.

# %% [markdown]
# <img src='data/space.jpg' width=400/>

# %% [markdown]
# **3)** На полке в случайном порядке расставлено
# 40 книг, среди которых находится трехтомник А. С.
# Пушкина. Найти вероятность того, что эти тома стоят в
# порядке возрастания слева направо (но не обязательно рядом).

# %% [markdown]
# **4)** 2 лыжника условились о встрече между 10 и 11 часами утра у подножия горы (склона), причем договорились ждать друг друга не более 10 минут, чтобы не замерзнуть. Считая, что момент прихода на встречу каждым выбирается наудачу в пределах указанного часа, найдите вероятность того, что встреча состоится.

# %% [markdown]
# **5)** На окружности берутся $N$ произвольных точек. Найти вероятность того, что они все будут лежать в одной полуокружности.

# %% [markdown]
# **6)** Наудачу выбирается хорда окружности в единичной окружности. Посчитайте вероятность, что она меньше длины вписанного в эту окружность треугольника. (Парадокс Бертрана)

# %% [markdown]
# ----------

# %% [markdown]
# ## ДЗ (все задачи по 1 баллу) <a class="anchor" id="chapter3"></a>

# %% [markdown]
# **1)** Даны натуральные числа $m$ и $n$, причем $m \leq n$. Из чисел $1,2,\ldots,n$ последовательно выбирают наугад два различных числа. Найдите вероятность того, что разность между первым выбранным числом и вторым будет не меньше $m$.

# %% [markdown]
# **2)** В программе к экзамену по теории вероятностей 75 вопросов. Студент знает 50 из них. В билете 3 вопроса. Найдите вероятность того, что студент знает хотя бы два вопроса из вытянутого им билета.

# %% [markdown]
# **3)** Вероятность увидеть машину на трассе за 30 минут - 0.95. Какая вероятность увидеть машину на трассе за 10 мин?

# %% [markdown]
# **4)** На плоскости, замощённой одинаковыми прямоугольниками со сторонами 10 и 20 (прямоугольники примыкают сторонами, 10 к 10, 20 к 20), рисуют случайную окружность радиуса 4. Найдите вероятность того, что окружность имеет общие точки ровно с тремя прямоугольниками.

# %% [markdown]
# **5)** Отрезок длины a случайным образом разделен на 3 части. Найти вероятность того, что длины хотя бы двоих частей не меньше, чем $a/5$.

# %% [markdown]
# ------

# %% [markdown]
# ## Гробы <a class="anchor" id="chapter4"></a>

# %% [markdown]
# **1. (0.5)** Пришелец сел на землю. Каждый день он с равной вероятностью может умереть, дуплицироваться (станет 2 пришельца), триплецироваться (станет 3 пришельца), и ничего не делать. Какова вероятность, что раса пришельцев самоуничтожится?

# %% [markdown]
# **2. (1)**  Ребята решили сыграть в тайного санту. Они написали свои имена на бумажках и сложили в шляпу, а сейчас вытягивают имена человека, кому они будут дарить подарок. Какова вероятность того, что никто не вытянет свое же имя?

# %% [markdown]
# **3.**
# Из чисел $\{1, 2, \ldots, N\}$ случайно выбирается число $a$. Найти вероятность $p_N$ того, что:
# * (а)**(0.5)** число $a$ не делится ни на $a_1$ ни на $a_2$, где $a_1$ и $a_2$ -- фиксированные натуральные взаимно простые числа;
# * (b)**(0.5)** число $a$ не делится ни на какое из чисел $a_1, a_2, \ldots, a_k$, где числа $a_i$ -- натуральные и попарно взаимно простые.
#
# Найти $\lim_{N\rightarrow\infty} p_N$ в случаях (a) и (b).

# %% [markdown]
# **4. (1)**
# Алиса и Боб подбрасывают правильную монетку и получают некоторую последовательность из орлов и решек. Мы хотим придумать такую игру, чтобы Алиса выиграла с вероятностью $p$, а Боб вероятностью $1-p$. Придумайте правила такой игры.
#
# Пояснение, например мы хотим, чтобы Алиса выиграла с вероятностью $\frac{3}{4}$, тогда мы устанавливаем правила, что если в за два хода мы получили хотя бы один орел, то тогда Алиса выигрывает.
#
# Замечание: $p$ может быть иррациональным.

# %% [markdown]
# **5. (0.5)** https://codeforces.com/problemset/problem/312/B

# %% [markdown]
# **6 (1)** Плоскость разграфлена параллельными прямыми, отстоящими друг от друга на расстоянии $2a$. На плоскости наудачу, бросается игла длины $2l (l \leq a)$. Найти вероятность того, что игла пересечет какую-нибудь прямую.

# %% [markdown]
# **7 (1)** Однородный прямой круговой конус с высотой h и радиусом основания r случайно бросается на горизонтальную плоскость.
# Найти вероятность того,
# * что он упадет на основание;
# * вычислить эту вероятность при $r = h$;
# * при каком отношении $r/h$ эта вероятность равна $1/4$?

# %% [markdown]
# **8(0.5)**
# Паша входит на станцию метро с кольцевым маршрутом. Ему нужно добраться до диаметрально противоположной станции, поэтому ему не важно на какой поезд садиться. Поезда приходят на станцию с равным интервалом в 1 час в каждую сторону. С какой вероятностью Паша сядет на один поезд или на другой поезд? (Можно считать, что поезда точки во времени и Паша садится в первую прибывшую точку на станцию)

# %% [markdown]
# **9(1)**
# Есть две урны с шарами, $N$ черных шаров и $N$ белых шаров.
# Можно любым способом разложить шары по урнам.
# После того как шары разложены урны будут перемешаны. (не будет известно где какая)
# И будет предложено из любой урны вытащить один шар.
# Какая оптимальная стратегия по раскладке шаров по урнам что бы вытащить белый шар.

# %% [markdown]
# ------------------

# %% [markdown]
# ## Мотивация

# %% [markdown]
# [Зачем нужна теория вероятностей](https://habr.com/ru/company/yasno_tv/blog/298898/)
#
# [Ускорение кода с помощью вероятности](https://habr.com/ru/company/yandex/blog/214745/)
#
# [Тервер для программистов](https://www.youtube.com/watch?v=zaOptBoqmUg)

# %% [markdown]
# ### Видеоматериалы (курс со Stepik)
# Чтобы получить доступ к видео, нужно создать аккаунт на stepik.org, а потом вступить в [курс "Теория вероятности" от CSC](https://stepik.org/course/3089)
#
# [Основы комбинаторики](https://stepik.org/lesson/48661/step/1)
#
# [Введение в вероятность](https://stepik.org/lesson/48659/step/3)
#
# [Вероятностные пространства](https://stepik.org/lesson/48660/step/1)

# %% [markdown]
# ### Теория (курс Черновой)
# [Основы комбинаторики](https://nsu.ru/mmf/tvims/chernova/tv/lec/node3.html#SECTION000210)
#
# [Элементарная теория вероятностей](https://nsu.ru/mmf/tvims/chernova/tv/lec/node4.html#SECTION000220)

# %% [markdown]
# ## Видеоматериалы,
#
# [Схема Бернулли](https://stepik.org/lesson/48665/step/1)
#
# [Теорема Пуассона](https://stepik.org/lesson/48671/step/1)

# %% [markdown]
# ## Теория
# [Схема Бернулли](https://nsu.ru/mmf/tvims/chernova/tv/lec/node17.html)
#
# [Теорема Пуассона](https://nsu.ru/mmf/tvims/chernova/tv/lec/node21.html)
